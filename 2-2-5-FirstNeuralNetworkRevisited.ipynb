# %% [markdown]
# <a href="https://colab.research.google.com/github/nmathew6/FundamentalsOfTinyML/blob/main/2-2-5-FirstNeuralNetworkRevisited.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# #### First lets re-train our original single layer network and see what the prediction is for X = 10.0 and what the learned weights are.

# %%
my_layer = keras.layers.Dense(units=1, input_shape=[1])
model = tf.keras.Sequential([my_layer])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 468ms/step - loss: 6.8136
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5496
# Epoch 3/500
# 1/1 [==============================] - 0s 11ms/step - loss: 4.5513
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.7621
# Epoch 5/500
# 1/1 [==============================] - 0s 14ms/step - loss: 3.1374
# Epoch 6/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2.6423
# Epoch 7/500
# 1/1 [==============================] - 0s 15ms/step - loss: 2.2492
# Epoch 8/500
# 1/1 [==============================] - 0s 16ms/step - loss: 1.9365
# Epoch 9/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.6870
# Epoch 10/500
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4873
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3269
# Epoch 12/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1976
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.98371]]

# %%
print(my_layer.get_weights())
# Out:
# [array([[1.997639]], dtype=float32), array([-0.9926799], dtype=float32)]

# %% [markdown]
# #### Next lets train a 2-layer network and see what its prediction and weights are.

# %%
my_layer_1 = keras.layers.Dense(units=2, input_shape=[1])
my_layer_2 = keras.layers.Dense(units=1)
model = tf.keras.Sequential([my_layer_1, my_layer_2])
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 336ms/step - loss: 15.4690
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 12.4250
# Epoch 3/500
# 1/1 [==============================] - 0s 7ms/step - loss: 9.9000
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 7.6826
# Epoch 5/500
# 1/1 [==============================] - 0s 7ms/step - loss: 5.7575
# Epoch 6/500
# 1/1 [==============================] - 0s 13ms/step - loss: 4.1797
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9909
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.1747
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6591
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3498
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.1641
# Epoch 12/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0451
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.999996]]

# %%
print(my_layer_1.get_weights())
print(my_layer_2.get_weights())
# Out:
# [array([[-0.21452834, -1.2242371 ]], dtype=float32), array([0.0821486 , 0.45257413], dtype=float32)]
# [array([[-0.292045 ],
#        [-1.5824937]], dtype=float32), array([-0.25981176], dtype=float32)]

# %% [markdown]
# #### Finally we can manually compute the output for our 2-layer network to better understand how it works.

# %%
value_to_predict = 10.0

layer1_w1 = (my_layer_1.get_weights()[0][0][0])
layer1_w2 = (my_layer_1.get_weights()[0][0][1])
layer1_b1 = (my_layer_1.get_weights()[1][0])
layer1_b2 = (my_layer_1.get_weights()[1][1])


layer2_w1 = (my_layer_2.get_weights()[0][0])
layer2_w2 = (my_layer_2.get_weights()[0][1])
layer2_b = (my_layer_2.get_weights()[1][0])

neuron1_output = (layer1_w1 * value_to_predict) + layer1_b1
neuron2_output = (layer1_w2 * value_to_predict) + layer1_b2

neuron3_output = (layer2_w1 * neuron1_output) + (layer2_w2 * neuron2_output) + layer2_b

print(neuron3_output)
# Out:
# [18.999994]
